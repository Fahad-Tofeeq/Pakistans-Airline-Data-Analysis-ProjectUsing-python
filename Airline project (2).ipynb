# %%
This Airline Project created by Fahad Tofeeq

# %% [markdown]
# Installation And Import Process

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Loading Data

# %% [markdown]
# Check Directory Contents:

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Airline project.ipynb', 'flight_analysis_output (1).xlsx']

# %% [markdown]
# Load DataFrame:

# %%
df = pd.read_excel("C:/Users/Fahad Tofeeq/Downloads/flight_analysis_output (1).xlsx")
df
# Out:
#         Unnamed: 0   index          airline   flight source_city  \
# 0                0       0              PIA  SG-8709   Islamabad
# 1                1       1              PIA  SG-8157   Islamabad
# 2                2       2         Air Blue   I5-764   Islamabad
# 3                3       3  Shaheen Airline   UK-995   Islamabad
# 4                4       4  Shaheen Airline   UK-963   Islamabad
# ...            ...     ...              ...      ...         ...
# 300148      300148  300148  Shaheen Airline   UK-822      Quetta
# 300149      300149  300149  Shaheen Airline   UK-826      Quetta
# 300150      300150  300150  Shaheen Airline   UK-832      Quetta
# 300151      300151  300151  Shaheen Airline   UK-828      Quetta
# 300152      300152  300152  Shaheen Airline   UK-822      Quetta
#
#        departure_time stops   arrival_time destination_city     class  \
# 0             Evening  zero          Night           Multan   Economy
# ...

# %% [markdown]
# • Verify Columns:

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'index', 'airline', 'flight', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left', 'price', 'columns']

# %% [markdown]
# Cleaning Data

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# index               0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# columns             0
# dtype: int64

# %% [markdown]
# Fill Missing Values:

# %%
df['duration']= df['duration'].fillna(df['duration'].mean())
print(df)
# Out:
#         Unnamed: 0   index          airline   flight source_city  \
# 0                0       0              PIA  SG-8709   Islamabad
# 1                1       1              PIA  SG-8157   Islamabad
# 2                2       2         Air Blue   I5-764   Islamabad
# 3                3       3  Shaheen Airline   UK-995   Islamabad
# 4                4       4  Shaheen Airline   UK-963   Islamabad
# ...            ...     ...              ...      ...         ...
# 300148      300148  300148  Shaheen Airline   UK-822      Quetta
# 300149      300149  300149  Shaheen Airline   UK-826      Quetta
# 300150      300150  300150  Shaheen Airline   UK-832      Quetta
# 300151      300151  300151  Shaheen Airline   UK-828      Quetta
# 300152      300152  300152  Shaheen Airline   UK-822      Quetta
#
#        departure_time stops   arrival_time destination_city     class  \
# 0             Evening  zero          Night           Multan   Economy
# ...

# %%
df['stops'] = df['stops'].fillna('unknown')
df.head()
# Out:
#    Unnamed: 0  index          airline   flight source_city departure_time  \
# 0           0      0              PIA  SG-8709   Islamabad        Evening
# 1           1      1              PIA  SG-8157   Islamabad  Early_Morning
# 2           2      2         Air Blue   I5-764   Islamabad  Early_Morning
# 3           3      3  Shaheen Airline   UK-995   Islamabad        Morning
# 4           4      4  Shaheen Airline   UK-963   Islamabad        Morning
#
#   stops   arrival_time destination_city    class  duration  days_left  price  \
# 0  zero          Night           Multan  Economy      2.17          1   5953
# 1  zero        Morning           Multan  Economy      2.33          1   5953
# 2  zero  Early_Morning           Multan  Economy      2.17          1   5956
# 3  zero      Afternoon           Multan  Economy      2.25          1   5955
# 4  zero        Morning           Multan  Economy      2.33          1   5955
#
#   columns
# 0  object
# 1  object
# 2  object
# 3  object
# ...

# %% [markdown]
# • Convert Data Types:

# %% [markdown]
# Check Data types

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# index                 int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# columns              object
# dtype: object

# %%
df['price'] =  df['price'].astype(float)
df['duration'] =  df['duration'].astype(float)
df.dtypes
# Out:
# Unnamed: 0            int64
# index                 int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price               float64
# columns              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   index             300153 non-null  int64
#  2   airline           300153 non-null  object
#  3   flight            300153 non-null  object
#  4   source_city       300153 non-null  object
#  5   departure_time    300153 non-null  object
#  6   stops             300153 non-null  object
#  7   arrival_time      300153 non-null  object
#  8   destination_city  300153 non-null  object
#  9   class             300153 non-null  object
#  10  duration          300153 non-null  float64
#  11  days_left         300153 non-null  int64
#  12  price             300153 non-null  float64
#  13  columns           300153 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 32.1+ MB

# %%
df.describe()
# Out:
#           Unnamed: 0          index       duration      days_left  \
# count  300153.000000  300153.000000  300153.000000  300153.000000
# mean   150076.000000  150076.000000      12.221021      26.004751
# std     86646.852011   86646.852011       7.191997      13.561004
# min         0.000000       0.000000       0.830000       1.000000
# 25%     75038.000000   75038.000000       6.830000      15.000000
# 50%    150076.000000  150076.000000      11.250000      26.000000
# 75%    225114.000000  225114.000000      16.170000      38.000000
# max    300152.000000  300152.000000      49.830000      49.000000
#
#                price
# count  300153.000000
# mean    20889.660523
# std     22697.767366
# min      1105.000000
# 25%      4783.000000
# 50%      7425.000000
# 75%     42521.000000
# max    123071.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'airline', 'flight', 'source_city',
#        'departure_time', 'stops', 'arrival_time', 'destination_city', 'class',
#        'duration', 'days_left', 'price', 'columns'],
#       dtype='object')

# %%
df['destination_city'].unique()
# Out:
# array(['Multan', 'Lahore', 'Karachi', 'GB', 'Islamabad', 'Quetta'],
#       dtype=object)

# %%
df['class'].unique()
# Out:
# array(['Economy', 'Business'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# index               0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# columns             0
# dtype: int64

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Airline project.ipynb', 'flight_analysis_output (1).xlsx']

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'index', 'airline', 'flight', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left', 'price', 'columns']

# %% [markdown]
# Standardize Formats

# %%
df['duration'] = df['duration'].astype(str) + 'hrs'
print(df['duration'].head())
# Out:
# 0    2.17hrs
# 1    2.33hrs
# 2    2.17hrs
# 3    2.25hrs
# 4    2.33hrs
# Name: duration, dtype: object

# %% [markdown]
# Remove Unnecessary Columns (e.g., columns):

# %%
df = df.drop(['columns','Unnamed: 0'], axis=1, errors='ignore')
print(df.columns.tolist())
# Out:
# ['index', 'airline', 'flight', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left', 'price']

# %% [markdown]
# Exploring Data

# %% [markdown]
# DataFrame Type:

# %%
print(type(df))
print(isinstance(df, pd.DataFrame))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# True

# %% [markdown]
# Column Data Types:

# %%
print(df.dtypes)
# Out:
# index                 int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration             object
# days_left             int64
# price               float64
# dtype: object

# %% [markdown]
# Filter Object Columns:

# %%
object_columns = df.select_dtypes(include=['object']).columns.tolist()
print("Object columns:", object_columns)
# Out:
# Object columns: ['airline', 'flight', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration']

# %% [markdown]
# Filter Float columns

# %%
columns = df.columns[1:5]
columns
# Out:
# Index(['airline', 'flight', 'source_city', 'departure_time'], dtype='object')

# %%
float_columns = df.select_dtypes(include= ['float']).columns.tolist()
print(f"Float Column is :{float_columns}")
# Out:
# Float Column is :['price']

# %% [markdown]
# Int columns

# %%
int_columns = df.select_dtypes(include = ["int"]).columns.tolist()
print(f"int Column is :{int_columns}")
# Out:
# int Column is :['index', 'days_left']

# %% [markdown]
# Summary Statistics:

# %%
print(df.describe()) 
print(df.describe(include='object'))
# Out:
#                index      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean   150076.000000      26.004751   20889.660523
# std     86646.852011      13.561004   22697.767366
# min         0.000000       1.000000    1105.000000
# 25%     75038.000000      15.000000    4783.000000
# 50%    150076.000000      26.000000    7425.000000
# 75%    225114.000000      38.000000   42521.000000
# max    300152.000000      49.000000  123071.000000
#                 airline  flight source_city departure_time   stops  \
# count            300153  300153      300153         300153  300153
# unique                6    1561           6              6       3
# top     Shaheen Airline  UK-706   Islamabad        Morning     one
# freq             127859    3235       61343          71146  250863
#
#        arrival_time destination_city    class duration
# count        300153           300153   300153   300153
# unique            6                6        2      476
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'airline', 'flight', 'source_city',
#        'departure_time', 'stops', 'arrival_time', 'destination_city', 'class',
#        'duration', 'days_left', 'price'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0', axis= 1 ,errors='ignore')
df
# Out:
#          index          airline   flight source_city departure_time stops  \
# 0            0              PIA  SG-8709   Islamabad        Evening  zero
# 1            1              PIA  SG-8157   Islamabad  Early_Morning  zero
# 2            2         Air Blue   I5-764   Islamabad  Early_Morning  zero
# 3            3  Shaheen Airline   UK-995   Islamabad        Morning  zero
# 4            4  Shaheen Airline   UK-963   Islamabad        Morning  zero
# ...        ...              ...      ...         ...            ...   ...
# 300148  300148  Shaheen Airline   UK-822      Quetta        Morning   one
# 300149  300149  Shaheen Airline   UK-826      Quetta      Afternoon   one
# 300150  300150  Shaheen Airline   UK-832      Quetta  Early_Morning   one
# 300151  300151  Shaheen Airline   UK-828      Quetta  Early_Morning   one
# 300152  300152  Shaheen Airline   UK-822      Quetta        Morning   one
#
#          arrival_time destination_city     class  duration  days_left    price
# ...

# %% [markdown]
# Unique Values:

# %%
print(df['airline'].unique()) 
print(df['stops'].value_counts())
# Out:
# ['PIA' 'Air Blue' 'Shaheen Airline' 'Serene Air' 'Air Sial' 'Fly Jinnah']
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64

# %% [markdown]
# Selecting and Filtering Data

# %%
selected_columns = df.iloc[:, 0:5]
print(selected_columns.head())
# Out:
#    index          airline   flight source_city departure_time
# 0      0              PIA  SG-8709   Islamabad        Evening
# 1      1              PIA  SG-8157   Islamabad  Early_Morning
# 2      2         Air Blue   I5-764   Islamabad  Early_Morning
# 3      3  Shaheen Airline   UK-995   Islamabad        Morning
# 4      4  Shaheen Airline   UK-963   Islamabad        Morning

# %%
print(df[['airline', 'flight', 'duration', 'price']].head())
# Out:
#            airline   flight duration   price
# 0              PIA  SG-8709  2.17hrs  5953.0
# 1              PIA  SG-8157  2.33hrs  5953.0
# 2         Air Blue   I5-764  2.17hrs  5956.0
# 3  Shaheen Airline   UK-995  2.25hrs  5955.0
# 4  Shaheen Airline   UK-963  2.33hrs  5955.0

# %%
high_price = df[df['price'] > 10000]
print(high_price[['airline', 'price']].head())
# Out:
#             airline    price
# 28              PIA  10260.0
# 29         Air Sial  10470.0
# 30       Serene Air  10575.0
# 31         Air Sial  10838.0
# 32  Shaheen Airline  12150.0

# %%
filtered = df[(df['price'] > 10000) & (df['class'] == 'Business')]
print(filtered[['airline', 'class', 'price']].head())
# Out:
#            airline     class    price
# 206666  Fly Jinnah  Business  25612.0
# 206667  Fly Jinnah  Business  25612.0
# 206668  Fly Jinnah  Business  42220.0
# 206669  Fly Jinnah  Business  44450.0
# 206670  Fly Jinnah  Business  46690.0

# %%
df.columns
# Out:
# Index(['index', 'airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price'],
#       dtype='object')

# %%
df['destination_city'].unique()
# Out:
# array(['Multan', 'Lahore', 'Karachi', 'GB', 'Islamabad', 'Quetta'],
#       dtype=object)

# %%
new1 = df[df['destination_city'].isin (['Islamabad','Lahore','Quetta'])]
print(new1[[ 'airline', 'flight','price']])
# Out:
#                 airline   flight    price
# 9982                PIA   SG-191   7425.0
# 9983           Air Blue  I5-1529   7426.0
# 9984    Shaheen Airline   UK-815   7425.0
# 9985    Shaheen Airline   UK-801   7425.0
# 9986    Shaheen Airline   UK-819   7425.0
# ...                 ...      ...      ...
# 295924       Fly Jinnah   AI-440  60260.0
# 295925       Fly Jinnah   AI-539  60260.0
# 295926       Fly Jinnah   AI-430  60260.0
# 295927       Fly Jinnah   AI-539  60260.0
# 295928       Fly Jinnah   AI-430  60260.0
#
# [148796 rows x 3 columns]

# %%
df['class'].unique()
# Out:
# array(['Economy', 'Business'], dtype=object)

# %%
premium = df[(df["price"]>10000) & (df['class']== "Business")]
premium[['airline', 'class', 'price']]
# Out:
#                 airline     class    price
# 206666       Fly Jinnah  Business  25612.0
# 206667       Fly Jinnah  Business  25612.0
# 206668       Fly Jinnah  Business  42220.0
# 206669       Fly Jinnah  Business  44450.0
# 206670       Fly Jinnah  Business  46690.0
# ...                 ...       ...      ...
# 300148  Shaheen Airline  Business  69265.0
# 300149  Shaheen Airline  Business  77105.0
# 300150  Shaheen Airline  Business  79099.0
# 300151  Shaheen Airline  Business  81585.0
# 300152  Shaheen Airline  Business  81585.0
#
# [93487 rows x 3 columns]

# %%
Economy =df[(df['price']<10000) & (df['class']=='Economy')]
print(Economy[['airline','class','price']])
# Out:
#                 airline    class   price
# 0                   PIA  Economy  5953.0
# 1                   PIA  Economy  5953.0
# 2              Air Blue  Economy  5956.0
# 3       Shaheen Airline  Economy  5955.0
# 4       Shaheen Airline  Economy  5955.0
# ...                 ...      ...     ...
# 206661  Shaheen Airline  Economy  7697.0
# 206662  Shaheen Airline  Economy  7709.0
# 206663  Shaheen Airline  Economy  8640.0
# 206664  Shaheen Airline  Economy  8640.0
# 206665  Shaheen Airline  Economy  8640.0
#
# [173653 rows x 3 columns]

# %%
Economy.describe()
# Out:
#                index      days_left          price
# count  173653.000000  173653.000000  173653.000000
# mean   102819.423569      29.129223    5248.050906
# std     59696.424959      12.205192    1898.246310
# min         0.000000       1.000000    1105.000000
# 25%     50622.000000      20.000000    3999.000000
# 50%    101455.000000      30.000000    5176.000000
# 75%    155458.000000      39.000000    6450.000000
# max    206665.000000      49.000000    9999.000000

# %%
df['price_days'] = df['price'] * df['days_left']
print(df[['price', 'days_left', 'price_days']].head())
# Out:
#     price  days_left  price_days
# 0  5953.0          1      5953.0
# 1  5953.0          1      5953.0
# 2  5956.0          1      5956.0
# 3  5955.0          1      5955.0
# 4  5955.0          1      5955.0

# %%
df['price_days'] = df['price'] * df['days_left']
print(df[['price','days_left','price_days',]])
# Out:
#           price  days_left  price_days
# 0        5953.0          1      5953.0
# 1        5953.0          1      5953.0
# 2        5956.0          1      5956.0
# 3        5955.0          1      5955.0
# 4        5955.0          1      5955.0
# ...         ...        ...         ...
# 300148  69265.0         49   3393985.0
# 300149  77105.0         49   3778145.0
# 300150  79099.0         49   3875851.0
# 300151  81585.0         49   3997665.0
# 300152  81585.0         49   3997665.0
#
# [300153 rows x 3 columns]

# %%
new_column_data = df['price'] * df['days_left']
df.insert(loc=2, column='price_days_inserted', value=new_column_data)
print(df.head())
# Out:
#    index          airline  price_days_inserted   flight source_city  \
# 0      0              PIA               5953.0  SG-8709   Islamabad
# 1      1              PIA               5953.0  SG-8157   Islamabad
# 2      2         Air Blue               5956.0   I5-764   Islamabad
# 3      3  Shaheen Airline               5955.0   UK-995   Islamabad
# 4      4  Shaheen Airline               5955.0   UK-963   Islamabad
#
#   departure_time stops   arrival_time destination_city    class duration  \
# 0        Evening  zero          Night           Multan  Economy  2.17hrs
# 1  Early_Morning  zero        Morning           Multan  Economy  2.33hrs
# 2  Early_Morning  zero  Early_Morning           Multan  Economy  2.17hrs
# 3        Morning  zero      Afternoon           Multan  Economy  2.25hrs
# 4        Morning  zero        Morning           Multan  Economy  2.33hrs
#
#    days_left   price  price_days
# 0          1  5953.0      5953.0
# 1          1  5953.0      5953.0
# ...

# %%
y= df.columns.tolist()
print(y)
for i in y:
    print(i)
# Out:
# ['index', 'airline', 'price_days_inserted', 'flight', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left', 'price', 'price_days']
# index
# airline
# price_days_inserted
# flight
# source_city
# departure_time
# stops
# arrival_time
# destination_city
# class
# duration
# days_left
# price
# price_days

# %%
avg_price = df.groupby('airline')['price'].mean()
print(avg_price)
# Out:
# airline
# Air Blue            4091.072742
# Air Sial            5324.216303
# Fly Jinnah         23507.019112
# PIA                 6179.278881
# Serene Air          5652.007595
# Shaheen Airline    30396.536302
# Name: price, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'airline', 'price_days_inserted', 'flight', 'source_city',
#        'departure_time', 'stops', 'arrival_time', 'destination_city', 'class',
#        'duration', 'days_left', 'price', 'price_days'],
#       dtype='object')

# %%
# Convert duration to numeric
df['duration'] = df['duration'].str.replace('hrs', '').astype(float)
# Group and aggregate
stats = df.groupby('class').agg({'price': 'mean', 'duration': 'mean'})
print(stats)
# Out:
#                  price   duration
# class
# Business  52540.081124  13.704274
# Economy    6572.342383  11.550060

# %%
by_city_class = df.groupby(['source_city', 'class'])['price'].mean()
print(by_city_class)
# Out:
# source_city  class
# GB           Business    52740.521251
#              Economy      6358.920050
# Islamabad    Business    48697.983457
#              Economy      6288.585423
# Karachi      Business    53723.539687
#              Economy      6582.057019
# Lahore       Business    56607.860536
#              Economy      7458.632354
# Multan       Business    50370.466200
#              Economy      6235.770619
# Quetta       Business    54140.530529
#              Economy      6606.279699
# Name: price, dtype: float64

# %%
df.select_dtypes(include = ['float']).columns.tolist()
# Out:
# ['price_days_inserted', 'duration', 'price', 'price_days']

# %%
df.columns
# Out:
# Index(['index', 'airline', 'price_days_inserted', 'flight', 'source_city',
#        'departure_time', 'stops', 'arrival_time', 'destination_city', 'class',
#        'duration', 'days_left', 'price', 'price_days'],
#       dtype='object')

# %% [markdown]
#  Visualizing Data
# • Price vs. Duration Scatter Plot:

# %%
import matplotlib.pyplot as plt
c = ["g",'r','b']
plt.scatter(df['duration'].astype(float), df['price'],color = 'c')
plt.xlabel('Duration (hrs)')
plt.ylabel('Price')
plt.title('Price vs. Duration')
plt.show()

# %%
import seaborn as sns
c =('g','r','b','m','p')
sns.boxplot(x='airline', y='price', data=df, color = 'c')
plt.title('Price Distribution by Airline')
plt.xticks(rotation=45)
plt.show()

# %%
# FacetGrid with scatter and regression
g = sns.FacetGrid(df, col='class', hue='class', palette='viridis', height=5)
g.map(sns.regplot, 'duration', 'price', scatter_kws={'alpha':0.6})
g.add_legend()
g.set_titles(col_template='{col_name} Class')
plt.suptitle('Price vs. Duration by Class with Regression Lines', y=1.02)
plt.show()

# %%
# Pivot data for heatmap
pivot_price = df.pivot_table(values='price', index='source_city', columns='destination_city', aggfunc='mean')

# Create heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(pivot_price, annot=True, fmt='.0f', cmap='magma')
plt.title('Average Price by Source and Destination City')
plt.xlabel('Destination City')
plt.ylabel('Source City')
plt.show()

# %% [markdown]
# Description: Visualizes mean prices as a matrix, with darker colors indicating higher prices. Annotations show exact values.

# %% [markdown]
# Pairplot for Numeric Variables (Price, Duration, Days Left)

# %%
# Pairplot with hue by class
sns.pairplot(df[['price', 'duration', 'days_left', 'class']], hue='class', palette='viridis')
plt.suptitle('Pairplot of Price, Duration, Days Left by Class', y=1.02)
plt.show()

# %% [markdown]
# Description: Shows pairwise relationships (e.g., price vs. duration) and distributions, with colors distinguishing Economy vs. Business. Useful for correlation spotting

# %% [markdown]
# Violin Plot for Price Distribution by Airline

# %%
# Violin plot with hue
plt.figure(figsize=(8, 6))
sns.violinplot(x='airline', y='price', hue='airline', data=df, palette='magma', inner='quartile', legend=False)
plt.title('Price Distribution by Airline')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Description: Displays price density and quartiles for each airline, highlighting variability and outliers

# %% [markdown]
# FacetGrid: Scatter Plot of Price vs. Duration by Class

# %%
# FacetGrid with scatter and regression
g = sns.FacetGrid(df, col='class', hue='class', palette='viridis', height=5)
g.map(sns.regplot, 'duration', 'price', scatter_kws={'alpha':0.6})
g.add_legend()
g.set_titles(col_template='{col_name} Class')
plt.suptitle('Price vs. Duration by Class with Regression Lines', y=1.02)
plt.show()

# %% [markdown]
# Description: Separate panels for each class showing price-duration relationship with trend lines, useful for comparing segments.

# %% [markdown]
# Time Series Line Plot: Average Price by Departure Hour

# %%
# Faceted boxplot
g = sns.catplot(x='airline', y='price', col='class', data=df, kind='box',hue='class', palette='magma', height=5, aspect=1.2)
g.set_xticklabels(rotation=45)
g.set_titles(col_template='{col_name} Class')
plt.suptitle('Price Distribution by Airline Faceted by Class', y=1.02)
plt.show()

# %%
# Histogram for price
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=20, kde=True, color='blue')
plt.title('Distribution of Flight Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Bar plot for flight counts by airline
plt.figure(figsize=(10, 6))
sns.countplot(x='airline', data=df,hue= 'class', palette='viridis')
plt.title('Number of Flights by Airline')
plt.xlabel('Airline')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
airline_counts = df['airline'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(airline_counts, labels=airline_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis', len(airline_counts)))
plt.title('Proportion of Flights by Airline')
plt.axis('equal')  # Equal aspect ratio for circular pie
plt.show()
